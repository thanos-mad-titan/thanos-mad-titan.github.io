# %% [markdown]
# This is my first jupyter notebook. I work on signal processing especially in compressive sensing, sparse representation. I also work on bayesian methods for inference. Hopefully some of that work will end up here.

# %%
# %matplotlib inline

import numpy as np
from matplotlib import pyplot as plt

y = np.random.randn(100)
x = np.linspace(0, 1, 100)

plt.figure();
plt.plot(x, y);

# %% [markdown]
# It seems it all works. :)
